# %%
import metacells as mc
import anndata as ad
import scanpy as sc
import numpy as np
from metacells import pipeline as pl

# %%
sc_data_path = "/Users/anushka/Undergraduate-Project/updated_dataset/sc_data.h5ad.1"
st_data_path = "/Users/anushka/Undergraduate-Project/updated_dataset/st_data.h5ad"

# Load the AnnData objects
adata = ad.read_h5ad(sc_data_path)

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=2000)
adata = adata[:, adata.var['highly_variable']]

sc.pp.pca(adata, n_comps=50)
sc.pp.neighbors(adata, n_neighbors=30, use_rep='X_pca')
# Out:
# /opt/anaconda3/envs/octopus/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:317: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm[key_obsm] = X_pca

# %%
print(adata.uns.keys())  # List all stored data
# Out:
# dict_keys(['hvg', 'log1p', 'pca', 'neighbors', 'downsample_samples'])

# %%
import metacells as mc

# Convert Scanpy's neighbors graph into Metacells format
adata.uns["obs_obs_knn_graph"] = adata.uns["neighbors"]  # Assign Scanpy's graph

# Now try computing similarity
mc.tl.compute_obs_obs_similarity(adata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 7
#       4 adata.uns["obs_obs_knn_graph"] = adata.uns["neighbors"]  # Assign Scanpy's graph
#       6 # Now try computing similarity
# ----> 7 mc.tl.compute_obs_obs_similarity(adata)
#
# File /opt/anaconda3/envs/octopus/lib/python3.9/site-packages/metacells/utilities/logging.py:384, in logged.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     379             if log_value is not None:
#     380                 logger().log(
#     381                     param_level, "%swith %s: %s", INDENT_SPACES[: 2 * INDENT_LEVEL], name, log_value
#     382                 )
# --> 384     return function(*args, **kwargs)
#     386 finally:
#     387     if logger().isEnabledFor(step_level):
#
# TypeError: compute_obs_obs_similarity() missing 1 required keyword-only argument: 'reproducible'

# %%
print(dir(mc.tl))
# Out:
# ['DefaultValues', 'Raise', 'Skip', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'apply', 'apply_obs_annotations', 'apply_var_annotations', 'bursty_lonely', 'candidates', 'choose_seeds', 'combine_masks', 'compute_candidate_metacells', 'compute_deviant_folds', 'compute_distinct_folds', 'compute_excluded_gene_umis', 'compute_inner_folds', 'compute_obs_obs_knn_graph', 'compute_obs_obs_similarity', 'compute_outliers_fold_factors', 'compute_outliers_matches', 'compute_projected_folds', 'compute_projected_fractions', 'compute_projection_weights', 'compute_similar_query_metacells', 'compute_stdev_logs', 'compute_subset_distinct_genes', 'compute_type_genes_normalized_variances', 'compute_var_var_knn_graph', 'compute_var_var_similarity', 'convey', 'convey_atlas_to_query', 'convey_group_to_obs', 'convey_obs_fractions_to_group', 'convey_obs_obs_to_group_group', 'convey_obs_to_group', 'convey_obs_to_obs', 'count_significant_
# ...

# %%
import metacells as mc

# Mark lateral genes (if required)
mc.tl.mark_lateral_genes(adata)

# Mark essential genes
mc.tl.mark_essential_genes(adata)

# Mark noisy genes
mc.tl.mark_noisy_genes(adata)

# Now, retry computing metacells
mc.pl.compute_direct_metacells(adata, target_metacell_size=50, random_seed=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 4
#       1 import metacells as mc
#       3 # Mark lateral genes (if required)
# ----> 4 mc.tl.mark_lateral_genes(adata)
#       6 # Mark essential genes
#       7 mc.tl.mark_essential_genes(adata)
#
# AttributeError: module 'metacells.tools' has no attribute 'mark_lateral_genes'

# %%
sc.pp.pca(st_data, n_comps=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sc.pp.pca(st_data, n_comps=50)
#
# File /opt/anaconda3/envs/octopus/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:281, in pca(***failed resolving arguments***)
#     277         X = X.toarray()
#     278     pca_ = PCA(
#     279         n_components=n_comps, svd_solver=svd_solver, random_state=random_state
#     280     )
# --> 281     X_pca = pca_.fit_transform(X)
#     282 elif issparse(X) and zero_center:
#     283     svd_solver = _handle_sklearn_args(svd_solver, "PCA (with sparse input)")
#
# File /opt/anaconda3/envs/octopus/lib/python3.9/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
# ...
